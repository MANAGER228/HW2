# %%
from bs4 import BeautifulSoup as bs
import requests
from pprint import pprint
import time
import re
import random

# %%
headers = {'User-agent': ''}

# %%
def hh(main_link, search_str, n_str):
    html = requests.get(main_link+'/search/vacancy?clusters=true&enable_snippets=true&text='+search_str+'&showClusters=true',headers=headers).text
    parsed_html = bs(html,'lxml')
    jobs = []
    for i in range(n_str):
        jobs_block = parsed_html.find('div',{'class':'vacancy-serp'})
        jobs_list = jobs_block.findChildren(recursive=False)
        for job in jobs_list:
            job_data={}
            req=job.find('span',{'class':'g-user-content'})
            if req!=None:
                main_info = req.findChild()
                job_name = main_info.getText()
                job_link = main_info['href']
                salary = job.find('div',{'class':'vacancy-serp-item__compensation'})
                if not salary:
                    salary_min=None
                    salary_max=None
                else:
                    salary=salary.getText().replace(u'\xa0', u'')
                    salaries=salary.split('-')
                    salaries[0] = re.sub(r'[^0-9]', '', salaries[0])
                    salary_min=int(salaries[0])
                    if len(salaries)>1:
                        salaries[1] = re.sub(r'[^0-9]', '', salaries[1])
                        salary_max=int(salaries[1])
                    else:
                        salary_max=None
                job_data['name'] = job_name
                job_data['salary_min'] = salary_min
                job_data['salary_max'] = salary_max
                job_data['link'] = job_link
                job_data['site'] = main_link
                jobs.append(job_data)
        time.sleep(random.randint(1,10))
        next_btn_block=parsed_html.find('a',{'class':'bloko-button HH-Pager-Controls-Next HH-Pager-Control'})
        next_btn_link=next_btn_block['href']
        html = requests.get(main_link+next_btn_link,headers=headers).text
        parsed_html = bs(html,'lxml')

    pprint(jobs)
    return jobs

# %%
search_str='Python'
n_str=2

hh('',search_str,n_str)
# Out:
# [{'link': 'https://ufa.hh.ru/vacancy/37827508?query=Python',
#   'name': 'Разработчик web-приложений Python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38323732?query=Python',
#   'name': 'Программист Python (Junior-Middle)',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37279680?query=Python',
#   'name': 'Python Developer',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38240529?query=Python',
#   'name': 'Data Engineer',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/35095020?query=Python',
#   'name': 'Senior Python Developer',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38123256?query=Python',
#   'name': 'Разработчик Python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38200974?query=Python',
#   'name': 'Аналитик данных / Data Analyst (Python/R)',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37483469?query=Python',
#   'name': 'Python разработчик',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38145341?query=Python',
#   'name': 'Разработчик Python (удаленная работа)',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38090292?query=Python',
#   'name': 'Senior python разработчик',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38249532?query=Python',
#   'name': 'Python-разработчик (Django, DRF)',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38254080?query=Python',
#   'name': 'Программист C++/Python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38290674?query=Python',
#   'name': 'Senior Python Developer (Болгария, София)',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38202973?query=Python',
#   'name': 'Программист-аналитик Python (анализ городских данных)',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/30005963?query=Python',
#   'name': 'Senior Python developer',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38036578?query=Python',
#   'name': 'Разработчик автоматических тестов GUI (Python, Squish)',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37797391?query=Python',
#   'name': 'Python / Django fullstack разработчик',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38308146?query=Python',
#   'name': 'Программист Python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37935294?query=Python',
#   'name': 'Senior Data Scientist',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37824260?query=Python',
#   'name': 'Data Scientist',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38299061?query=Python',
#   'name': 'Программист Python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37711158?query=Python',
#   'name': 'Junior Machine Learning Engineer',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38350786?query=Python',
#   'name': 'Python developer',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37856225?query=Python',
#   'name': 'QA / Автотестировщик (Python)',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37115745?query=Python',
#   'name': 'Python senior developer',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37817365?query=Python',
#   'name': 'Программист C++/Python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/36541868?query=Python',
#   'name': 'Программист Python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38279802?query=Python',
#   'name': 'Backend разработчик на python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38342697?query=Python',
#   'name': 'Junior NLP engineer / Python developer',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/36774670?query=Python',
#   'name': 'Начинающий backend-разработчик (Python)',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37571622?query=Python',
#   'name': 'Python-разработчик системы защиты',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37227093?query=Python',
#   'name': 'Python developer удаленно',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38247304?query=Python',
#   'name': 'Junior python разработчик',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37913284?query=Python',
#   'name': 'Python Developer',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38163869?query=Python',
#   'name': 'Junior Data Scientist',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37928725?query=Python',
#   'name': 'Junior Python Developer (разработчик)',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37340422?query=Python',
#   'name': 'Backend разработчик (Python)',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38161319?query=Python',
#   'name': 'Data Engineer / Python Developer',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/35419959?query=Python',
#   'name': 'QA Automation Engineer (Python)',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38209764?query=Python',
#   'name': 'Программист Python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38232775?query=Python',
#   'name': 'Разработчик Python Baсkend',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/36541983?query=Python',
#   'name': 'Программист Python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37227127?query=Python',
#   'name': 'Python developer (удаленно)',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37836538?query=Python',
#   'name': 'Программист Python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37856031?query=Python',
#   'name': 'Python разработчик (моделирование движения транспорта в крупных '
#           'городах)',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38090271?query=Python',
#   'name': 'Data Scientist (Computer Vision)',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37402770?query=Python',
#   'name': 'Программист Python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37003043?query=Python',
#   'name': 'Senior Python Developer',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38122267?query=Python',
#   'name': 'Программист Python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37673751?query=Python',
#   'name': 'Django разработчик (python)',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37757725?query=Python',
#   'name': 'Web-разработчик на Python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38065880?query=Python',
#   'name': 'Python Developer',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38112756?query=Python',
#   'name': 'Python Developer на бэкенд',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37983959?query=Python',
#   'name': 'Программист Python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38203770?query=Python',
#   'name': 'Python разработчик',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38297625?query=Python',
#   'name': 'Программист Python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37953250?query=Python',
#   'name': 'Программист Python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/36267290?query=Python',
#   'name': 'Python developer',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38344580?query=Python',
#   'name': 'Программист Python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38079250?query=Python',
#   'name': 'Python разработчик',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38222169?query=Python',
#   'name': 'Python developer (Web Development)',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38339932?query=Python',
#   'name': 'Python developer',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38092920?query=Python',
#   'name': 'Python Developer (Numpy/pandas)',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37901764?query=Python',
#   'name': 'Backend-разработчик на Python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38172830?query=Python',
#   'name': 'Специалист по Machine learning (3D-алгоритмы)',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38353417?query=Python',
#   'name': 'Senior Machine Learning Engineer',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37962587?query=Python',
#   'name': 'Backend разработчик на python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38230580?query=Python',
#   'name': 'Full-stack tester',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37997200?query=Python',
#   'name': 'Разработчик Python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38238604?query=Python',
#   'name': 'Python Developer',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38203811?query=Python',
#   'name': 'Python разработчик',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/36449432?query=Python',
#   'name': 'Python middle developer',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38306439?query=Python',
#   'name': 'Python developer',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38330677?query=Python',
#   'name': 'Программист Python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38159690?query=Python',
#   'name': 'ML Developer/Data scientist',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37998939?query=Python',
#   'name': 'Python-разработчик в команду Data Science',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38037181?query=Python',
#   'name': 'Разработчик Python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/36742022?query=Python',
#   'name': 'C++/python разработчик',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38226764?query=Python',
#   'name': 'Программист Python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38106530?query=Python',
#   'name': 'Программист Python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37227041?query=Python',
#   'name': 'Python developer удаленно',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37227103?query=Python',
#   'name': 'Python developer удаленно',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38327837?query=Python',
#   'name': 'Python Developer',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37993806?query=Python',
#   'name': 'Разработчик на Python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37935113?query=Python',
#   'name': 'Программист Python / С++',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38201930?query=Python',
#   'name': 'Python Backend Developer',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38237520?query=Python',
#   'name': 'FullStack-разработчик Python/ Программист Python',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/36267171?query=Python',
#   'name': 'Python developer',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38014145?query=Python',
#   'name': 'Python Middle программист разработчик удалённо',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37227109?query=Python',
#   'name': 'Python developer (удаленно)',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37996813?query=Python',
#   'name': 'Senior Python Developer',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38088239?query=Python',
#   'name': 'Full-stack разработчик (Python, JavaScript)',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37977483?query=Python',
#   'name': 'Backend-разработчик (Python)',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37957150?query=Python',
#   'name': 'Backend-разработчик / Python developer',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38323541?query=Python',
#   'name': 'Python разработчик в myTarget',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38275106?query=Python',
#   'name': 'Python разработчик',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37765040?query=Python',
#   'name': 'Python разработчик',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/37961734?query=Python',
#   'name': 'Backend Developer JS + Python (Django)',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38087204?query=Python',
#   'name': 'Senior Python developer',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'},
#  {'link': 'https://ufa.hh.ru/vacancy/38350129?query=Python',
#   'name': 'Backend разработчик Python / Django (Middle)',
#   'salary_max': None,
#   'salary_min': None,
#   'site': 'https://ufa.hh.ru'}]
# [{'name': 'Разработчик web-приложений Python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37827508?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Программист Python (Junior-Middle)',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38323732?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python Developer',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37279680?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Data Engineer',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38240529?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Senior Python Developer',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/35095020?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Разработчик Python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38123256?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Аналитик данных / Data Analyst (Python/R)',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38200974?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python разработчик',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37483469?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Разработчик Python (удаленная работа)',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38145341?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Senior python разработчик',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38090292?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python-разработчик (Django, DRF)',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38249532?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Программист C++/Python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38254080?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Senior Python Developer (Болгария, София)',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38290674?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Программист-аналитик Python (анализ городских данных)',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38202973?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Senior Python developer',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/30005963?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Разработчик автоматических тестов GUI (Python, Squish)',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38036578?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python / Django fullstack разработчик',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37797391?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Программист Python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38308146?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Senior Data Scientist',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37935294?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Data Scientist',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37824260?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Программист Python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38299061?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Junior Machine Learning Engineer',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37711158?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python developer',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38350786?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'QA / Автотестировщик (Python)',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37856225?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python senior developer',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37115745?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Программист C++/Python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37817365?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Программист Python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/36541868?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Backend разработчик на python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38279802?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Junior NLP engineer / Python developer',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38342697?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Начинающий backend-разработчик (Python)',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/36774670?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python-разработчик системы защиты',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37571622?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python developer удаленно',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37227093?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Junior python разработчик',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38247304?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python Developer',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37913284?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Junior Data Scientist',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38163869?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Junior Python Developer (разработчик)',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37928725?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Backend разработчик (Python)',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37340422?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Data Engineer / Python Developer',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38161319?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'QA Automation Engineer (Python)',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/35419959?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Программист Python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38209764?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Разработчик Python Baсkend',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38232775?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Программист Python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/36541983?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python developer (удаленно)',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37227127?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Программист Python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37836538?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python разработчик (моделирование движения транспорта в крупных городах)',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37856031?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Data Scientist (Computer Vision)',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38090271?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Программист Python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37402770?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Senior Python Developer',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37003043?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Программист Python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38122267?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Django разработчик (python)',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37673751?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Web-разработчик на Python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37757725?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python Developer',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38065880?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python Developer на бэкенд',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38112756?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Программист Python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37983959?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python разработчик',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38203770?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Программист Python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38297625?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Программист Python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37953250?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python developer',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/36267290?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Программист Python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38344580?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python разработчик',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38079250?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python developer (Web Development)',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38222169?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python developer',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38339932?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python Developer (Numpy/pandas)',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38092920?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Backend-разработчик на Python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37901764?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Специалист по Machine learning (3D-алгоритмы)',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38172830?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Senior Machine Learning Engineer',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38353417?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Backend разработчик на python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37962587?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Full-stack tester',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38230580?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Разработчик Python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37997200?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python Developer',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38238604?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python разработчик',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38203811?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python middle developer',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/36449432?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python developer',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38306439?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Программист Python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38330677?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'ML Developer/Data scientist',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38159690?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python-разработчик в команду Data Science',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37998939?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Разработчик Python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38037181?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'C++/python разработчик',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/36742022?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Программист Python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38226764?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Программист Python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38106530?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python developer удаленно',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37227041?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python developer удаленно',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37227103?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python Developer',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38327837?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Разработчик на Python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37993806?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Программист Python / С++',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37935113?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python Backend Developer',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38201930?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'FullStack-разработчик Python/ Программист Python',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38237520?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python developer',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/36267171?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python Middle программист разработчик удалённо',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38014145?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python developer (удаленно)',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37227109?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Senior Python Developer',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37996813?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Full-stack разработчик (Python, JavaScript)',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38088239?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Backend-разработчик (Python)',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37977483?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Backend-разработчик / Python developer',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37957150?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python разработчик в myTarget',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38323541?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python разработчик',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38275106?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Python разработчик',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37765040?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Backend Developer JS + Python (Django)',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/37961734?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Senior Python developer',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38087204?query=Python',
#   'site': 'https://ufa.hh.ru'},
#  {'name': 'Backend разработчик Python / Django (Middle)',
#   'salary_min': None,
#   'salary_max': None,
#   'link': 'https://ufa.hh.ru/vacancy/38350129?query=Python',
#   'site': 'https://ufa.hh.ru'}]
